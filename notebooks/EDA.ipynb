# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/tharu/Desktop/customer_churn_prediction_project/data/raw/telco.csv")

# %%
df.head()
# Out:
#   Customer ID  Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0  8779-QRDMV    Male   78       No            Yes      No         No
# 1  7495-OOKFY  Female   74       No            Yes     Yes        Yes
# 2  1658-BYGOY    Male   71       No            Yes      No        Yes
# 3  4598-XLKNJ  Female   78       No            Yes     Yes        Yes
# 4  4846-WHAFZ  Female   80       No            Yes     Yes        Yes
#
#    Number of Dependents        Country       State  ...  \
# 0                     0  United States  California  ...
# 1                     1  United States  California  ...
# 2                     3  United States  California  ...
# 3                     1  United States  California  ...
# 4                     1  United States  California  ...
#
#   Total Extra Data Charges  Total Long Distance Charges  Total Revenue  \
# 0                       20                         0.00          59.65
# ...

# %%
df.shape
# Out:
# (7043, 50)

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Under 30', 'Senior Citizen', 'Married',
#        'Dependents', 'Number of Dependents', 'Country', 'State', 'City',
#        'Zip Code', 'Latitude', 'Longitude', 'Population', 'Quarter',
#        'Referred a Friend', 'Number of Referrals', 'Tenure in Months', 'Offer',
#        'Phone Service', 'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Satisfaction Score', 'Customer Status', 'Churn Label',
#        'Churn Score', 'CLTV', 'Churn Category', 'Churn Reason'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 50 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   str
#  1   Gender                             7043 non-null   str
#  2   Age                                7043 non-null   int64
#  3   Under 30                           7043 non-null   str
#  4   Senior Citizen                     7043 non-null   str
#  5   Married                            7043 non-null   str
#  6   Dependents                         7043 non-null   str
#  7   Number of Dependents               7043 non-null   int64
#  8   Country                            7043 non-null   str
#  9   State                              7043 non-null   str
#  10  City                               7043 non-null   str
#  11  Zip Code                           7043 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age  Number of Dependents      Zip Code     Latitude  \
# count  7043.000000           7043.000000   7043.000000  7043.000000
# mean     46.509726              0.468692  93486.070567    36.197455
# std      16.750352              0.962802   1856.767505     2.468929
# min      19.000000              0.000000  90001.000000    32.555828
# 25%      32.000000              0.000000  92101.000000    33.990646
# 50%      46.000000              0.000000  93518.000000    36.205465
# 75%      60.000000              0.000000  95329.000000    38.161321
# max      80.000000              9.000000  96150.000000    41.962127
#
#          Longitude     Population  Number of Referrals  Tenure in Months  \
# count  7043.000000    7043.000000          7043.000000       7043.000000
# mean   -119.756684   22139.603294             1.951867         32.386767
# std       2.154425   21152.392837             3.001199         24.542061
# ...

# %%
# Exploratory Data Analysis (EDA)

#In this section, we inspect the quality of the dataset before applying machine learning models.

# %%
df.isnull().sum()
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Under 30                                0
# Senior Citizen                          0
# Married                                 0
# Dependents                              0
# Number of Dependents                    0
# Country                                 0
# State                                   0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Population                              0
# Quarter                                 0
# Referred a Friend                       0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges       0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Handling Missing Values
#
# The dataset contains meaningful missing values. Instead of dropping these rows, we replace them with appropriate labels based on business understanding.

# %%
df["Offer"] = df["Offer"].fillna("No Offer")

# %%
df["Internet Type"] = df["Internet Type"].fillna("No Internet")

# %%
df["Churn Category"] = df["Churn Category"].fillna("Not Churned")

# %%
df["Churn Reason"] = df["Churn Reason"].fillna("Not Churned")

# %%
df.isnull().sum()
# Out:
# Customer ID                          0
# Gender                               0
# Age                                  0
# Under 30                             0
# Senior Citizen                       0
# Married                              0
# Dependents                           0
# Number of Dependents                 0
# Country                              0
# State                                0
# City                                 0
# Zip Code                             0
# Latitude                             0
# Longitude                            0
# Population                           0
# Quarter                              0
# Referred a Friend                    0
# Number of Referrals                  0
# Tenure in Months                     0
# Offer                                0
# Phone Service                        0
# Avg Monthly Long Distance Charges    0
# Multiple Lines                       0
# Internet Service                     0
# ...

# %% [markdown]
# # Target Variable Analysis
#
# The target variable is **Churn Label**, which indicates whether a customer has churned (Yes) or stayed (No). Understanding its distribution helps identify class imbalance before model training.

# %%
df["Churn Label"].value_counts()
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
pip install matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Target Variable Visualization
#
# Visualizing the target variable helps understand the class distribution before model training.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6,4))
sns.countplot(x="Churn Label", data=df)
plt.title("Customer Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Number Of Customers")

plt.show()

# %%
numerical_columns=df.select_dtypes(include=["int64", "float64"]).columns
categorical_columns=df.select_dtypes(include=["object"]).columns
# Out:
# C:\Users\tharu\AppData\Local\Temp\ipykernel_15884\1150067163.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns=df.select_dtypes(include=["object"]).columns

# %%
print("Numerical Columns:")
print(numerical_columns)
# Out:
# Numerical Columns:
# Index(['Age', 'Number of Dependents', 'Zip Code', 'Latitude', 'Longitude',
#        'Population', 'Number of Referrals', 'Tenure in Months',
#        'Avg Monthly Long Distance Charges', 'Avg Monthly GB Download',
#        'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Satisfaction Score', 'Churn Score', 'CLTV'],
#       dtype='str')

# %%
print("Categorical Columns:")
print(categorical_columns)
# Out:
# Categorical Columns:
# Index(['Customer ID', 'Gender', 'Under 30', 'Senior Citizen', 'Married',
#        'Dependents', 'Country', 'State', 'City', 'Quarter',
#        'Referred a Friend', 'Offer', 'Phone Service', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Online Security', 'Online Backup',
#        'Device Protection Plan', 'Premium Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Streaming Music', 'Unlimited Data', 'Contract',
#        'Paperless Billing', 'Payment Method', 'Customer Status', 'Churn Label',
#        'Churn Category', 'Churn Reason'],
#       dtype='str')

# %%
print("Number of numerical columns", len(numerical_columns))
print("Number of Categorical columns", len(categorical_columns) )
# Out:
# Number of numerical columns 19
# Number of Categorical columns 31

# %% [markdown]
# # Day 4 - Exploratory Data Analysis (EDA)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("ggplot")

# %%
numerical_columns
# Out:
# Index(['Age', 'Number of Dependents', 'Zip Code', 'Latitude', 'Longitude',
#        'Population', 'Number of Referrals', 'Tenure in Months',
#        'Avg Monthly Long Distance Charges', 'Avg Monthly GB Download',
#        'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Satisfaction Score', 'Churn Score', 'CLTV'],
#       dtype='str')

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Age"], bins=20, kde=True)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Observation
#
# - Customer ages range approximately from 18 to 80 years.
# - Most customers belong to the age group of 20–65 years.
# - The number of customers decreases after the age of 65.
# - The age distribution is fairly balanced without significant skewness.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Monthly Charge"], bins=20, kde=True)

plt.title("Monthly Charge Distribution")
plt.xlabel("Monthly Charge")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# # Observation
#
# - Monthly charges range approximately from $18 to $120.
# - Most customers fall into two major pricing groups: around $20–30 and $70–100.
# - The distribution is bimodal rather than normally distributed.
# - No significant outliers are observed.

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Tenure in Months"], bins=20, kde=True)

plt.title("Tenure in Months Distribution")
plt.xlabel("Tenure in Months")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Observation
#
# - Customer tenure ranges from 1 to 72 months.
# - A large number of customers are new (1–5 months).
# - Another large group has remained with the company for around 70–72 months.
# - Fewer customers fall in the middle tenure range.
# - The distribution is bimodal, indicating two major customer groups.

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Total Charges"], bins=20, kde=True)

plt.title("Total Charges Distribution")
plt.xlabel("Total Charges")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# # Observation
#
# - Total Charges range from approximately 0 to 8700.
# - Most customers have relatively low total charges.
# - The distribution is positively (right) skewed.
# - The number of customers decreases as total charges increase.
# - No obvious anomalies are observed.

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Total Revenue"], bins=20, kde=True)

plt.title("Total Revenue Distribution")
plt.xlabel("Total Revenue")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# # Observation
#
# - Total Revenue ranges from approximately 0 to 12000.
# - Most customers have generated relatively low revenue.
# - Only a small number of customers generated very high revenue.
# - The distribution is positively (right) skewed.
# - No obvious anomalies are observed.

# %%
plt.figure(figsize=(8,5))

sns.countplot(x = "Satisfaction Score", data=df)

plt.title("Satisfaction Score Distribution")
plt.xlabel("Satisfsction Score")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# # Observation
#
# - Satisfaction scores range from 1 to 5.
# - Most customers have a satisfaction score of 3.
# - Satisfaction score 4 is the second most common rating.
# - Score 5 occurs less frequently than score 4.
# - Score 2 has the fewest customers, while score 1 has slightly more.
# - Overall, most customers are neutral to satisfied.

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Churn Score"], bins=20, kde=True)

plt.title("Churn Score Distribution")
plt.xlabel("Churn Score")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# Observation:
# Most customers have Churn Scores between 60 and 80, indicating that a large proportion of customers have a moderate to high risk of churn. Very few customers have extremely low churn scores.

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["CLTV"], bins=20, kde=True)

plt.title("Customer Lifetime Value (CLTV) Distribution")
plt.xlabel("CLTV")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# Observation:
# Most customers have a CLTV between 4000 and 6000, indicating that the majority of customers contribute a moderate to high lifetime value. Retaining these customers can significantly improve long-term business revenue.

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Gender", data=df)

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Number Of Customers")

plt.show()

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %% [markdown]
# Observation:
# The dataset has an almost equal distribution of male (3555) and female (3488) customers. The difference is very small, indicating that gender is well balanced in the dataset.

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Senior Citizen", data=df)

plt.title("Senior Citizen Distribution")
plt.xlabel("Senior Citizen")
plt.ylabel("Number Of Customers")

plt.show()

df["Senior Citizen"].value_counts()
# Out:
# Senior Citizen
# No     5901
# Yes    1142
# Name: count, dtype: int64

# %% [markdown]
# Observation:
# The majority of customers (5901) are not senior citizens, while only 1142 customers are senior citizens. This indicates that senior citizens represent a relatively small portion of the customer base.

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="Married", data=df)

plt.title("Married Customer Distribution")
plt.xlabel("Married")
plt.ylabel("Number of Customers")

plt.show()

# %%
df["Married"].value_counts()
# Out:
# Married
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %% [markdown]
# Observation:
# The dataset contains a nearly balanced distribution of married (3402) and unmarried (3641) customers. There is no significant imbalance between the two groups.

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="Internet Type", data=df)

plt.title("Internet Type Distribution")
plt.xlabel("Internet Type")
plt.ylabel("Number of Customers")

plt.show()

# %%
df["Internet Type"].value_counts()
# Out:
# Internet Type
# Fiber Optic    3035
# DSL            1652
# No Internet    1526
# Cable           830
# Name: count, dtype: int64

# %% [markdown]
# Observation:
# Fiber Optic is the most commonly used internet service with 3035 customers, followed by DSL (1652) and customers with no internet connection (1526). Cable has the lowest number of customers (830).

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="Contract", data=df)

plt.title("Contract Distribution")
plt.xlabel("Contract")
plt.ylabel("Number of Customers")

plt.show()

# %%
df["Contract"].value_counts()
# Out:
# Contract
# Month-to-Month    3610
# Two Year          1883
# One Year          1550
# Name: count, dtype: int64

# %% [markdown]
# Observation:
# Most customers (3610) are on Month-to-Month contracts. Two-Year contracts are the second most common (1883), while One-Year contracts are the least common (1550).

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="Payment Method", data=df)

plt.title("Payment Method Distribution")
plt.xlabel("Payment Method")
plt.ylabel("Number of Customers")

plt.show()

# %%
df["Payment Method"].value_counts()
# Out:
# Payment Method
# Bank Withdrawal    3909
# Credit Card        2749
# Mailed Check        385
# Name: count, dtype: int64

# %% [markdown]
# Observation:
# Most customers use Bank Withdrawal (3909), followed by Credit Card (2749). Mailed Check is the least preferred payment method, with only 385 customers.

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="Offer", data=df)

plt.title("Offer Distribution")
plt.xlabel("Offer")
plt.ylabel("Number of Customers")

plt.show()

# %%
df["Offer"].value_counts()
# Out:
# Offer
# No Offer    3877
# Offer B      824
# Offer E      805
# Offer D      602
# Offer A      520
# Offer C      415
# Name: count, dtype: int64

# %% [markdown]
# Observation:
# Most customers (3877) did not receive any promotional offer. Among the offered plans, Offer B (824) and Offer E (805) are the most common, while Offer C (415) is the least common.

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="Customer Status", data=df)

plt.title("Customer Status Distribution")
plt.xlabel("Customer Status")
plt.ylabel("Number of Customers")

plt.show()

# %%
df["Customer Status"].value_counts()
# Out:
# Customer Status
# Stayed     4720
# Churned    1869
# Joined      454
# Name: count, dtype: int64

# %% [markdown]
# Observation:
# Most customers have stayed with the company (4720). Churned customers account for 1869 records, while newly joined customers are the smallest group with 454 records.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df[numerical_columns].corr(), annot=True,cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Observation:
#
# 1. Total Charges and Total Revenue have a very strong positive correlation (0.97), indicating that customers who spend more overall generate higher revenue.
#
# 2. Tenure in Months has a strong positive correlation with Total Charges and Total Revenue, showing that long-term customers contribute more revenue.
#
# 3. Monthly Charge has a moderate positive correlation with Total Charges, indicating that customers with higher monthly plans generally accumulate higher total charges.
#
# 4. Satisfaction Score has a moderate negative correlation with Churn Score, suggesting that customers with higher satisfaction tend to have lower churn scores.
#
# 5. Most of the remaining numerical features have weak correlations, indicating that they are largely independent of one another.

# %% [markdown]
# #Bivariate analysis

# %%
#Tenure in Montha vs Churn Label
plt.figure(figsize=(8,5))
sns.boxplot(
    x="Churn Label",
    y="Tenure in Months",
    data=df
)
plt.title("Tenure in Months vs Churn Label")
plt.xlabel("Churn Label")
plt.ylabel("Tenure in Months")
plt.show()

# %% [markdown]
# Observation:
#
# Customers who churn (Yes) generally have a much lower tenure than customers who do not churn (No). The median tenure of churned customers is around 10 months, whereas the median tenure of retained customers is around 38 months. This indicates that customers who have been with the company for a longer period are less likely to churn. Therefore, "Tenure in Months" appears to be one of the strongest predictors of customer churn.

# %%
#Monthly Charge vs Churn Label
plt.figure(figsize=(8,5))

sns.boxplot(
    x="Churn Label",
    y="Monthly Charge",
    data=df
)

plt.title("Monthly Charge vs Churn Label")
plt.xlabel("Churn Label")
plt.ylabel("Monthly Charge")

plt.show()

# %% [markdown]
# Observation:
#
# Customers who churn (Yes) generally have higher monthly charges than customers who do not churn (No). The median monthly charge for churned customers is around $80, while the median for retained customers is around $64. This suggests that customers paying higher monthly charges are more likely to leave the service. Therefore, "Monthly Charge" appears to be an important factor influencing customer churn.

# %%
#Total charges vs churn label
plt.figure(figsize=(8,5))

sns.boxplot(
    x="Churn Label",
    y="Total Charges",
    data=df
)

plt.title("Total Charges vs Churn Label")
plt.xlabel("Churn Label")
plt.ylabel("Total Charges")

plt.show()

# %% [markdown]
# Observation:
#
# Customers who did not churn (No) generally have higher total charges than customers who churned (Yes). The median total charges for retained customers are significantly higher than those for churned customers. This is because customers who stay with the company for a longer time continue paying monthly bills, resulting in higher accumulated charges. Therefore, Total Charges is an important feature and is closely related to customer retention.

# %%
#Satisfaction Score vs churn label
plt.figure(figsize=(8,5))

sns.boxplot(
    x="Churn Label",
    y="Satisfaction Score",
    data=df
)

plt.title("Satisfaction Score vs Churn Label")
plt.xlabel("Churn Label")
plt.ylabel("Satisfaction Score")

plt.show()

# %% [markdown]
# Observation:
#
# Customers who did not churn generally have higher satisfaction scores (mostly between 3 and 4, with some scoring 5), whereas customers who churned have much lower satisfaction scores (mostly between 1 and 2). This indicates a strong negative relationship between customer satisfaction and churn. As satisfaction increases, the likelihood of churn decreases.

# %%
#Customer Life Time Value vs churn label
plt.figure(figsize=(8,5))

sns.boxplot(
    x="Churn Label",
    y="CLTV",
    data=df
)

plt.title("CLTV(Customer Life Time Value) vs Churn Label")
plt.xlabel("Churn Label")
plt.ylabel("CLTV")

plt.show()

# %% [markdown]
# Observation:
#
# Customers who did not churn have a slightly higher Customer Lifetime Value (CLTV) than customers who churned. However, the distributions of both groups overlap considerably, indicating that CLTV alone is not a strong indicator of customer churn.

# %%
#Churn label vs Churn Score
plt.figure(figsize=(8,5))

sns.boxplot(
    x="Churn Label",
    y="Churn Score",
    data=df
)

plt.title("Churn Score vs Churn Label")
plt.xlabel("Churn Label")
plt.ylabel("Churn Score")

plt.show()

# %% [markdown]
# Observation:
#
# Customers who churned have significantly higher churn scores than customers who stayed. The median churn score for churned customers is around 80–85, whereas non-churned customers have a median score of around 50. This indicates a strong positive relationship between churn score and customer churn, making it an important feature for churn prediction.

# %%
#preprocessing
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Under 30', 'Senior Citizen', 'Married',
#        'Dependents', 'Number of Dependents', 'Country', 'State', 'City',
#        'Zip Code', 'Latitude', 'Longitude', 'Population', 'Quarter',
#        'Referred a Friend', 'Number of Referrals', 'Tenure in Months', 'Offer',
#        'Phone Service', 'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Satisfaction Score', 'Customer Status', 'Churn Label',
#        'Churn Score', 'CLTV', 'Churn Category', 'Churn Reason'],
#       dtype='str')

# %%
#Target Variable
y = df["Churn Label"]
y.head()
# Out:
# 0    Yes
# 1    Yes
# 2    Yes
# 3    Yes
# 4    Yes
# Name: Churn Label, dtype: str

# %%
x = df.drop(columns=[
"Customer ID",
"Churn Label",
"Customer Status",
"Churn Score",
"Churn Category",
"Churn Reason",

"Zip Code",
"Latitude",
"Longitude",
"Population",
"Country",
"State",
"City",
"Quarter"
])

# %%
x.head()
# Out:
#    Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0    Male   78       No            Yes      No         No
# 1  Female   74       No            Yes     Yes        Yes
# 2    Male   71       No            Yes      No        Yes
# 3  Female   78       No            Yes     Yes        Yes
# 4  Female   80       No            Yes     Yes        Yes
#
#    Number of Dependents Referred a Friend  Number of Referrals  \
# 0                     0                No                    0
# 1                     1               Yes                    1
# 2                     3                No                    0
# 3                     1               Yes                    1
# 4                     1               Yes                    1
#
#    Tenure in Months  ... Paperless Billing   Payment Method  Monthly Charge  \
# 0                 1  ...               Yes  Bank Withdrawal           39.65
# 1                 8  ...               Yes      Credit Card           80.65
# ...

# %%
# Train-Test Split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
# Identify column types
categorical_cols = x.select_dtypes(include=["object"]).columns.tolist()
numerical_cols = x.select_dtypes(exclude=["object"]).columns.tolist()

print("Categorical Columns:", len(categorical_cols))
print(categorical_cols)

print("\nNumerical Columns:", len(numerical_cols))
print(numerical_cols)
# Out:
# Categorical Columns: 22
# ['Gender', 'Under 30', 'Senior Citizen', 'Married', 'Dependents', 'Referred a Friend', 'Offer', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Internet Type', 'Online Security', 'Online Backup', 'Device Protection Plan', 'Premium Tech Support', 'Streaming TV', 'Streaming Movies', 'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing', 'Payment Method']
#
# Numerical Columns: 14
# ['Age', 'Number of Dependents', 'Number of Referrals', 'Tenure in Months', 'Avg Monthly Long Distance Charges', 'Avg Monthly GB Download', 'Monthly Charge', 'Total Charges', 'Total Refunds', 'Total Extra Data Charges', 'Total Long Distance Charges', 'Total Revenue', 'Satisfaction Score', 'CLTV']
# ...

# %%
print("x Shape", x.shape)
print("y Shape", y.shape)
# Out:
# x Shape (7043, 36)
# y Shape (7043,)

# %%
#Encoding target variable
y = y.map({"No" : 0, "Yes" : 1})
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Churn Label, dtype: int64

# %%
categorical_cols = x.select_dtypes(include=["object"]).columns.tolist()
numerical_cols = x.select_dtypes(exclude=["object"]).columns.tolist()

print("Categorical:", len(categorical_cols))
print("Numerical:", len(numerical_cols))
# Out:
# Categorical: 22
# Numerical: 14
# C:\Users\tharu\AppData\Local\Temp\ipykernel_15884\2959761742.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = x.select_dtypes(include=["object"]).columns.tolist()

# %%
#Train test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#finding catogorical columns
x.select_dtypes(include="object").columns
# Out:
# C:\Users\tharu\AppData\Local\Temp\ipykernel_15884\2519663530.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   x.select_dtypes(include="object").columns
# Index(['Gender', 'Under 30', 'Senior Citizen', 'Married', 'Dependents',
#        'Referred a Friend', 'Offer', 'Phone Service', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Online Security', 'Online Backup',
#        'Device Protection Plan', 'Premium Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Streaming Music', 'Unlimited Data', 'Contract',
# ...

# %%
print(x.columns.tolist())
# Out:
# ['Gender', 'Age', 'Under 30', 'Senior Citizen', 'Married', 'Dependents', 'Number of Dependents', 'Referred a Friend', 'Number of Referrals', 'Tenure in Months', 'Offer', 'Phone Service', 'Avg Monthly Long Distance Charges', 'Multiple Lines', 'Internet Service', 'Internet Type', 'Avg Monthly GB Download', 'Online Security', 'Online Backup', 'Device Protection Plan', 'Premium Tech Support', 'Streaming TV', 'Streaming Movies', 'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds', 'Total Extra Data Charges', 'Total Long Distance Charges', 'Total Revenue', 'Satisfaction Score', 'CLTV']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler

preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numerical_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)
    ]
)

# %%
from xgboost import XGBClassifier

pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("model", XGBClassifier(
        random_state=42,
        eval_metric="logloss"
    ))
])

# %%
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Age',
#                                                    'Number of Dependents',
#                                                    'Number of Referrals',
#                                                    'Tenure in Months',
#                                                    'Avg Monthly Long Distance '
#                                                    'Charges',
#                                                    'Avg Monthly GB Download',
#                                                    'Monthly Charge',
#                                                    'Total Charges',
#                                                    'Total Refunds',
#                                                    'Total Extra Data Charges',
#                                                    'Total Long Distance '
# ...

# %%
pred_pipeline = pipeline.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

score = accuracy_score(y_test, pred_pipeline)
print(f"Accuracy: {score*100:.2f}%")
# Out:
# Accuracy: 94.75%

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, pred_pipeline))
# Out:
# [[984  25]
#  [ 49 351]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, pred_pipeline))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      1009
#            1       0.93      0.88      0.90       400
#
#     accuracy                           0.95      1409
#    macro avg       0.94      0.93      0.93      1409
# weighted avg       0.95      0.95      0.95      1409

# %%
import joblib

joblib.dump(pipeline, "../models/churn_pipeline.pkl")
# Out:
# ['../models/churn_pipeline.pkl']

# %%
print(x.columns.tolist())
# Out:
# ['Gender', 'Age', 'Under 30', 'Senior Citizen', 'Married', 'Dependents', 'Number of Dependents', 'Referred a Friend', 'Number of Referrals', 'Tenure in Months', 'Offer', 'Phone Service', 'Avg Monthly Long Distance Charges', 'Multiple Lines', 'Internet Service', 'Internet Type', 'Avg Monthly GB Download', 'Online Security', 'Online Backup', 'Device Protection Plan', 'Premium Tech Support', 'Streaming TV', 'Streaming Movies', 'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds', 'Total Extra Data Charges', 'Total Long Distance Charges', 'Total Revenue', 'Satisfaction Score', 'CLTV']

# %%
print(df["Contract"].unique())
print(df["Payment Method"].unique())
print(df["Internet Type"].unique())
print(df["Offer"].unique())
# Out:
# <ArrowStringArray>
# ['Month-to-Month', 'One Year', 'Two Year']
# Length: 3, dtype: str
# <ArrowStringArray>
# ['Bank Withdrawal', 'Credit Card', 'Mailed Check']
# Length: 3, dtype: str
# <ArrowStringArray>
# ['DSL', 'Fiber Optic', 'Cable', 'No Internet']
# Length: 4, dtype: str
# <ArrowStringArray>
# ['No Offer', 'Offer E', 'Offer D', 'Offer C', 'Offer B', 'Offer A']
# Length: 6, dtype: str
